# %%
import wandb
api = wandb.Api()

# Project is specified by <entity/project-name>
runs = api.runs("ogait/thesis_gravity_spy")
summary_list = [] 
config_list = [] 
name_list = [] 
for run in runs: 
    # run.summary are the output key/values like accuracy.
    # We call ._json_dict to omit large files 
    summary_list.append(run.summary._json_dict) 

    # # run.config is the input metrics.
    # # We remove special values that start with _.
    config = {k:v for k,v in run.config.items() if k in ('architecture', 'view', 'mixed_precision')}
    config_list.append(config) 

    # run.name is the name of the run.
    name_list.append(run.name)       

import pandas as pd 
summary_df = pd.DataFrame.from_records(summary_list) 
config_df = pd.DataFrame.from_records(config_list) 
name_df = pd.DataFrame({'name': name_list}) 
all_df = pd.concat([name_df, config_df,summary_df], axis=1)

# %%
all_df = all_df[:20]

# %%
all_df
# Out:
#                   name         view architecture  mixed_precision   best_f1  \
# 0     jumping-sweep-20    encoded14     resnet34            False  0.966232
# 1    fanciful-sweep-19   encoded124     resnet34            False  0.960791
# 2        firm-sweep-18  encoded1234     resnet34            False  0.971646
# 3    fearless-sweep-17       merged     resnet34            False  0.972317
# 4   sparkling-sweep-16      single1     resnet34            False  0.937866
# 5      expert-sweep-15    encoded14     resnet34             True  0.964744
# 6       swept-sweep-14   encoded124     resnet34             True  0.969610
# 7      golden-sweep-13  encoded1234     resnet34             True  0.965010
# 8     crimson-sweep-12       merged     resnet34             True  0.965351
# 9   celestial-sweep-11      single1     resnet34             True  0.946108
# 10    hopeful-sweep-10    encoded14     resnet18            False  0.961594
# 11        easy-sweep-9   encoded124     resnet18            False  0.964025
# 12    confused-sweep-8  encoded1234     resnet18            False  0.966768
# 13         icy-sweep-7       merged     resnet18            False  0.967517
# 14   chocolate-sweep-6      single1     resnet18            False  0.938640
# 15      golden-sweep-5    encoded14     resnet18             True  0.963156
# 16       sleek-sweep-4   encoded124     resnet18             True  0.971585
# 17        fast-sweep-3  encoded1234     resnet18             True  0.964724
# 18  effortless-sweep-2       merged     resnet18             True  0.961590
# 19     silvery-sweep-1      single1     resnet18             True  0.944375
#
#     accuracy  image_size  train_samples_per_sec          lr_0  _step  ...  \
# 0   0.985248  [140, 170]             873.547970  7.213657e-09    929  ...
# 1   0.983696  [140, 170]             869.058048  7.213657e-09    929  ...
# 2   0.988354  [140, 170]             857.061290  2.388666e-09    929  ...
# 3   0.987578  [280, 340]             255.508882  3.452673e-09    929  ...
# 4   0.971273  [140, 170]             874.583139  1.652553e-09    929  ...
# 5   0.983696  [140, 170]            1333.581850  8.672723e-09    929  ...
# 6   0.984472  [140, 170]            1360.476163  2.619120e-08    929  ...
# 7   0.984472  [140, 170]            1310.709775  1.507147e-08    929  ...
# 8   0.986801  [280, 340]             452.813911  4.151026e-09    929  ...
# 9   0.975932  [140, 170]            1367.883008  1.811989e-08    929  ...
# 10  0.981366  [140, 170]            1496.558303  2.871808e-09    929  ...
# 12      84.173630  0.01  0.949999   93.398982
# 13     176.914769  0.01  0.949999  196.088387
# 14      64.300427  0.01  0.949999   72.453718
# 15      56.096825  0.01  0.949999   63.298819
# 16      62.635301  0.01  0.949999   71.939607
# 17      69.980208  0.01  0.949999   78.587229
# 18     118.089521  0.01  0.949999  131.435816
# 19      58.705448  0.01  0.949999   69.419433
#
# [20 rows x 26 columns]

# %%
all_df.to_csv("logs/02_mixed_precision_new.csv")

# %%
import pandas as pd 
all_df = pd.read_csv('logs/02_mixed_precision_new.csv')

# %%
no_merged_df = all_df.loc[all_df['view'] != 'merged']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))

plt.subplot(1, 2, 1)
ax = sns.barplot(x='mixed_precision', y='total_runtime', data=all_df, errwidth=0, alpha=0.60)
sns.stripplot(x='mixed_precision', y='total_runtime',  data=all_df, linewidth=1, size=8)
plt.xlabel('mixed precision', size='large')
plt.ylabel('total runtime (s)', size='large')
plt.ylim([0, 300])
#plt.legend(frameon=False)

plt.subplot(1, 2, 2)
ax = sns.barplot(x='mixed_precision', y='f1_score', data=all_df, errwidth=0, alpha=0.6)
sns.stripplot(x='mixed_precision', y='f1_score', data=all_df, linewidth=1, size=8)
plt.ylabel('f1 score', size='large')
plt.xlabel('mixed precision', size='large')
plt.ylim([0.9, 1])

fig.tight_layout()
fig.savefig('../figs/glitches/02_mixed_precision_new.png', dpi=300)

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))

plt.subplot(1, 2, 1)
ax = sns.boxplot(x='mixed_precision', y='total_runtime', data=all_df, width=0.7)
plt.xlabel('mixed precision', size='large')
plt.ylabel('total runtime (s)', size='large')
plt.ylim([50, 150])

plt.subplot(1, 2, 2)
ax = sns.boxplot(x='mixed_precision', y='best_f1', data=all_df, width=0.7)
plt.ylabel('best_f1', size='large')
plt.xlabel('mixed precision', size='large')
plt.ylim([0.9, 1])

fig.tight_layout()

# %%
all_df.groupby('mixed_precision').mean()['total_runtime']
# Out:
# mixed_precision
# False    115.059737
# True      87.553208
# Name: total_runtime, dtype: float64

# %%
(115.06-87.55)/115.06
# Out:
# 0.23909264731444468

# %%
no_merged_df.groupby('mixed_precision').mean()['total_runtime']
# Out:
# mixed_precision
# False    87.100972
# True     71.540941
# Name: total_runtime, dtype: float64

# %%
(87.10-71.54)/87.10
# Out:
# 0.17864523536165314

# %%
import numpy as np

# %%
x = np.linspace(0, 900, 100)
m = - 1/10000
b = 0
y = m * x + b
plt.xlim([0, 900])
plt.ylim([-0.03, 0.005])
plt.plot(x, y)

# %%
m * 300 - m*360
# Out:
# 0.006000000000000002

# %%
x = np.linspace(0, 900, 100)
m = - 0.01 / 300
b = 0
y = m * x + b
plt.xlim([0, 900])
plt.ylim([-0.03, 0.005])
plt.plot(x, y)

# %%
m * 300 - m*360
# Out:
# 0.002
